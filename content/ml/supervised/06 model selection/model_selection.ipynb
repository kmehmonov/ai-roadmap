# %% [markdown]
# train_test_split, KFold, StratifiedKFold, cross_val_score, GridSearchCV, RandomizerSearchCV

# %% [markdown]
# Lesson 10 (Random Forest) – Introduce GridSearchCV and RandomizedSearchCV for hyperparameter tuning.
