# %%
import numpy as np
from matplotlib import pyplot as plt
arr = np.load('img_data.npy')
arr.shape
# Out:
# (28, 28, 4)

# %%
plt.imshow(arr)
plt.show()

# %%
mask1 = arr.sum(axis=1).sum(axis=1) != 0
mask2 = arr.sum(axis=0).sum(axis=1) != 0
plt.imshow(arr[mask1][:, mask2])
plt.show()

# %%
arr1 = arr[mask1][:, mask2]

# %%
arr2 = (arr @ np.array([0.2989, 0.5870, 0.1140, 0]))

# %%
plt.imshow(arr2, cmap='binary')
plt.show()

# %%
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
plt.imshow(x_train[y_train == 6][5], cmap='binary')
plt.show()

# %%
model = tf.keras.models.load_model('models/mymodel.keras')
# Out:
# d:\ai-roadmap\projects\digit_rocognize\.env\lib\site-packages\keras\src\saving\saving_lib.py:719: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 8 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
model.get_weights()[0].shape
# Out:
# (784, 80)

# %%
model.get_weights()[1].shape
# Out:
# (80,)

# %%
model.get_weights()[2].shape
# Out:
# (80, 50)

# %%
model.get_weights()[3].shape
# Out:
# (50,)

# %%
model.get_weights()[4].shape
# Out:
# (50, 10)

# %%
model.get_weights()[5].shape
# Out:
# (10,)

# %%
tf.keras.utils.plot_model(model, show_shapes=True, show_layer_names=True)
