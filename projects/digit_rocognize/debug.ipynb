# %%
import numpy as np
from matplotlib import pyplot as plt
arr = np.load('img_data.npy')
arr.shape
# Out:
# (28, 28, 4)

# %%
plt.imshow(arr)
plt.show()

# %%
mask1 = arr.sum(axis=1).sum(axis=1) != 0
mask2 = arr.sum(axis=0).sum(axis=1) != 0
plt.imshow(arr[mask1][:, mask2])
plt.show()

# %%
arr1 = arr[mask1][:, mask2]

# %%
arr2 = (arr1 @ np.array([0.2989, 0.5870, 0.1140, 0])).round()

# %%
plt.imshow(arr2)
plt.show()

# %%
(arr @ np.array([0.2989, 0.5870, 0.1140, 0])).shape
# Out:
# (28, 28)
